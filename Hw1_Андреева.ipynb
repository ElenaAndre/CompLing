# %% [markdown]
# **Домашняя работа 1**

# %% [markdown]
# **Задача 1
# Условный оператор if-elif-else**

# %%
a = float(input('Оцените силу вашей душевной боли по шкале от 0 до 10.\nНапример:\n0-1 Вы пролили кофе на рубашку\n1-4 Вам предстоит сделать что-то малоприятное\n5-7.5 Впереди дело, от которого зависит Ваша карьера\n8-10 Все, что Вы упели сделать, пропало\n '))
if a < 0.7:
    print('Кажется, вы испытываете легкое огорчение. Как человек в короткой поездке в метро, забывший дома наушники')
elif 0.7 <= a <= 4.2:
    print('Вы встревожены - почти как человек, которому придется звонить по телефону, и это в эпоху мессенджеров! То самое чувство, когда начинаете нервно репетировать в голове диалог...')
elif 4.3 <= a <= 6.9:
    print('Вы чувствуете себя, как студент во время сессии. Всю ночь готовился, но все равно, будто не готов')
elif 7<= a <= 8:
    print('Ощущение такое, будто git не работает. Это невыносимо!')
elif 8.1 <= a <=10:
    print('Ваш мир будто рухнул')
else:
    print('Максимальная отметка шкалы - 10')
# Out:
# Оцените силу вашей душевной боли по шкале от 0 до 10.
# Например:
# 0-1 Вы пролили кофе на рубашку
# 1-4 Вам предстоит сделать что-то малоприятное
# 5-7.5 Впереди дело, от которого зависит Ваша карьера
# 8-10 Все, что Вы упели сделать, пропало
#  10.1
# Максимальная отметка шкалы - 10

# %% [markdown]
# **Задача 2
# Список, цикл for**

# %% [markdown]
# **Примечание!!!
# Через цикл for у меня не убирается последний элемент, который начинается с "В новом году". Я нашла в интернете такое объяснение, что при удалении элемента его индекс занимает следующий элемент, а этот индекс цикл for уже не проверяет. Как сделать так, чтобы удалился и последний подходящий элемент, я пока не понимаю.
# В отдельной ячейке привожу другой код, без цикла for, но тут вроде работает.
# Было бы здорово получить комментарий, как все-таки решить эту задачу через цикл for, указаный в условии.**

# %%
import random

hse_prediction = [
    ['Слушайте каждого. Идеи приходят отовсюду.'],
    ['Скоро контрольная точка по нелюбимому предмету('],
    ['В новом году обещаю себе смотреть не больше трех серий сериала за раз'],
    ['Угостите преподавателя конфеткой!'],
    ['Хорошие новости придут к вам по  Яндекс почте.'],
    ['Что ни делается - все к лучшему, и даже первая пара, ожидающая Вас в обновлённом расписании.'],
    ['Делайте то, чего просит душа и тело - не идите на пары!'],
    ['Пора собирать чемоданы: Вас ждет экспедиция на Сахалин!'],
    ['Пришло время сдать все долги.'],
    ['Вы не получите автомат по физре в следующем полугодии.'],
    ['В новом году обещаю себе спать'],
    ['Если вы ждали знака - то ВОТ ОН! Срочно участвуйте в ближайшей конференции!'],
    ['Вам повысят стипендию на 1000 рублей в этом году.'],
    ['Ураааааааааааа! Завтра одни только  лекции!'],
    ['Все лучшее происходит,когда Вас нет на паре!'],
    ['На мобильность только в Питер'],
    ['В новом году обещаю себе защитить диссертацию'],
    ['В новом году обещаю себе запомнить имена одногруппников'],
    ['Через час  Вы снова проголодаетесь. Шоколад можно найти в магазине.']
        ]
for i in hse_prediction:
    if i[0].startswith('В новом году'):
        q = hse_prediction.index(i)
        del hse_prediction[q]
# print(hse_prediction)

prediction = random.choice(hse_prediction)
print(prediction)
# Out:
# ['Что ни делается - все к лучшему, и даже первая пара, ожидающая Вас в обновлённом расписании.']

# %%
import random

hse_prediction = [
    ['Слушайте каждого. Идеи приходят отовсюду.'],
    ['Скоро контрольная точка по нелюбимому предмету('],
    ['В новом году обещаю себе смотреть не больше трех серий сериала за раз'],
    ['Угостите преподавателя конфеткой!'],
    ['Хорошие новости придут к вам по  Яндекс почте.'],
    ['Что ни делается - все к лучшему, и даже первая пара, ожидающая Вас в обновлённом расписании.'],
    ['Делайте то, чего просит душа и тело - не идите на пары!'],
    ['Пора собирать чемоданы: Вас ждет экспедиция на Сахалин!'],
    ['Пришло время сдать все долги.'],
    ['Вы не получите автомат по физре в следующем полугодии.'],
    ['В новом году обещаю себе спать'],
    ['Если вы ждали знака - то ВОТ ОН! Срочно участвуйте в ближайшей конференции!'],
    ['Вам повысят стипендию на 1000 рублей в этом году.'],
    ['Ураааааааааааа! Завтра одни только  лекции!'],
    ['Все лучшее происходит,когда Вас нет на паре!'],
    ['На мобильность только в Питер'],
    ['В новом году обещаю себе защитить диссертацию'],
    ['В новом году обещаю себе запомнить имена одногруппников'],
    ['Через час  Вы снова проголодаетесь. Шоколад можно найти в магазине.']
        ]

hse_prediction_new = list(filter(lambda x: not x[0].startswith('В новом году'), hse_prediction))

# print(hse_prediction_new)

prediction = random.choice(hse_prediction_new)
print(prediction)
# Out:
# ['Пришло время сдать все долги.']

# %% [markdown]
# **Задача 3
# Множества**

# %%
# В архиве не хватает двух открыток: от Петры из Парижа и от Ивана из Москвы. Добавьте их в архив Алисы.
postcards = {
    "Maria": "London",
    "Lorenzo": "Milan",
    "Oleg": "Canberra",
    "Hans": "Calgary",
    "Mark": "Milan",
    "Alex": "Krakow",
    "Julia": "Murmansk"

}
postcards["Petra"] = "Paris"
postcards["Ivan"] = "Moscow"
for i in postcards:
    print(i, postcards[i])
# Out:
# Maria London
# Lorenzo Milan
# Oleg Canberra
# Hans Calgary
# Mark Milan
# Alex Krakow
# Julia Murmansk
# Petra Paris
# Ivan Moscow

# %%
# Открытка, присланная Олегом, на самом деле не из Канберры, а из Сиднея. Исправьте город на верный, изменив значение по ключу в словаре.
postcards["Oleg"] = "Sydney"
for i in postcards:
    print(i, postcards[i])
# Out:
# Maria London
# Lorenzo Milan
# Oleg Sydney
# Hans Calgary
# Mark Milan
# Alex Krakow
# Julia Murmansk
# Petra Paris
# Ivan Moscow

# %%
# Алиса говорит, что в ее коллекции более 10 уникальных городов. Сколько их на самом деле? Выведите названия этих городов.
postcards_values = set(postcards.values())
# print(postcards_values)
print(len(postcards_values))
for i in postcards_values:
    print(i)
# Out:
# 8
# Milan
# Sydney
# Calgary
# Moscow
# Paris
# Murmansk
# Krakow
# London
